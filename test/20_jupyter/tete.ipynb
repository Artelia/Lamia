# %%
import Lamia

# %%
2+2
# Out:
# 4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10)
line, = plt.plot(x, np.sin(x), linewidth = 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-fdcb12f61088> in <module>
#       3 import numpy as np
#       4 x = np.linspace(0,10)
# ----> 5 line, = plt.plot(x, np.sin(x), '..', linewidth = 2)
#
# C:\OSGEO4~1\apps\Python37\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#    2748     return gca().plot(
# -> 2749         *args, scalex=scalex, scaley=scaley, data=data, **kwargs)
#    2750
#    2751 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# C:\OSGEO4~1\apps\Python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# ...
